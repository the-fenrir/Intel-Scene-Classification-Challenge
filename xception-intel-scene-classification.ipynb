# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# import tensorflow as tf
# import tensorflow.keras as keras

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
input0 = "../input/intel-data-scene/scene_classification/scene_classification"
print(os.listdir(input0))

# Any results you write to the current directory are saved as output.b
# Out:
# ['train', 'test', 'train.csv']

# %%
dataset = pd.read_csv(input0+'/train.csv')

# %%
dataset.head()
# Out:
#   image_name  label
# 0      0.jpg      0
# 1      1.jpg      4
# 2      2.jpg      5
# 3      4.jpg      0
# 4      7.jpg      4

# %%
#Using Transfer Learning
from tensorflow.python.keras.applications import Xception
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Flatten, GlobalAveragePooling2D

# %%
num_classes = 6
xception_weights_path = '../input/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5'

model = Sequential()
model.add(Xception(include_top=False, pooling='avg', weights=xception_weights_path))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.layers[0].trainable = False

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Model)             (None, 2048)              20861480
# _________________________________________________________________
# dense (Dense)                (None, 6)                 12294
# =================================================================
# Total params: 20,873,774
# Trainable params: 12,294
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
from tensorflow.python.keras.applications.xception import preprocess_input
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

# %%
image_size = 150
batch_size=15
data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
from sklearn.model_selection import train_test_split

train, validate = train_test_split(dataset, test_size=0.20, random_state=0)
train = train.reset_index(drop=True)
train['label'] = train['label'].astype(str)
validate = validate.reset_index(drop=True)
validate['label'] = validate['label'].astype(str)

# %%
train['label'].value_counts().plot.bar()

# %%
validate['label'].value_counts().plot.bar()

# %%
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
train_generator = datagen.flow_from_dataframe(
    train, 
    input0 + "/train/", 
    x_col='image_name',
    y_col='label',
    target_size=(image_size, image_size),
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 13627 images belonging to 6 classes.

# %%
validate_generator = datagen.flow_from_dataframe(
    validate, 
    input0 + "/train/", 
    x_col='image_name',
    y_col='label',
    target_size=(image_size, image_size),
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 3407 images belonging to 6 classes.

# %%
example = train.sample(n=1).reset_index(drop=True)
example_generator = datagen.flow_from_dataframe(
    example, 
    input0 + "/train/", 
    x_col='image_name',
    y_col='label',
    target_size=(image_size, image_size),
    class_mode='categorical',
)

plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Found 1 images belonging to 1 classes.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
model_checkpoint = ModelCheckpoint("weights.{epoch:02d}-{val_loss:.4f}.hdf5", verbose=1, period=5)
earlystop = EarlyStopping(patience=10, verbose=1)
learning_rate_reduction = ReduceLROnPlateau(patience=2, factor=0.5, verbose=1)
callbacks = [model_checkpoint, earlystop, learning_rate_reduction]

FAST_RUN = False
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validate_generator,
    validation_steps=validate.shape[0]//batch_size,
    steps_per_epoch=train.shape[0]//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 908/908 [==============================] - 83s 91ms/step - loss: 0.6967 - acc: 0.7668 - val_loss: 0.4665 - val_acc: 0.8485
# Epoch 2/50
# 908/908 [==============================] - 54s 59ms/step - loss: 0.5225 - acc: 0.8206 - val_loss: 0.4321 - val_acc: 0.8535
# Epoch 3/50
# 908/908 [==============================] - 53s 58ms/step - loss: 0.4872 - acc: 0.8338 - val_loss: 0.4269 - val_acc: 0.8567
# Epoch 4/50
# 908/908 [==============================] - 52s 57ms/step - loss: 0.4758 - acc: 0.8338 - val_loss: 0.4126 - val_acc: 0.8567
# Epoch 5/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.4591 - acc: 0.8391
# Epoch 00005: saving model to weights.05-0.4162.hdf5
# 908/908 [==============================] - 53s 58ms/step - loss: 0.4589 - acc: 0.8392 - val_loss: 0.4162 - val_acc: 0.8608
# Epoch 6/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.4494 - acc: 0.8434
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 908/908 [==============================] - 52s 57ms/step - loss: 0.4492 - acc: 0.8435 - val_loss: 0.4174 - val_acc: 0.8564
# Epoch 7/50
# 908/908 [==============================] - 53s 58ms/step - loss: 0.4274 - acc: 0.8507 - val_loss: 0.4047 - val_acc: 0.8631
# Epoch 8/50
# 908/908 [==============================] - 52s 57ms/step - loss: 0.4171 - acc: 0.8534 - val_loss: 0.3985 - val_acc: 0.8649
# Epoch 9/50
# 908/908 [==============================] - 51s 57ms/step - loss: 0.4167 - acc: 0.8545 - val_loss: 0.3926 - val_acc: 0.8623
# Epoch 10/50
# 906/908 [============================>.] - ETA: 0s - loss: 0.4260 - acc: 0.8525
# Epoch 00010: saving model to weights.10-0.3990.hdf5
# 908/908 [==============================] - 52s 57ms/step - loss: 0.4258 - acc: 0.8526 - val_loss: 0.3990 - val_acc: 0.8673
# Epoch 11/50
# 908/908 [==============================] - 52s 58ms/step - loss: 0.4018 - acc: 0.8564 - val_loss: 0.3880 - val_acc: 0.8664
# Epoch 12/50
# 908/908 [==============================] - 51s 56ms/step - loss: 0.4034 - acc: 0.8574 - val_loss: 0.3990 - val_acc: 0.8587
# Epoch 13/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.4029 - acc: 0.8590
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 908/908 [==============================] - 53s 59ms/step - loss: 0.4027 - acc: 0.8591 - val_loss: 0.3984 - val_acc: 0.8649
# Epoch 14/50
# 908/908 [==============================] - 52s 57ms/step - loss: 0.4018 - acc: 0.8549 - val_loss: 0.3851 - val_acc: 0.8681
# Epoch 15/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.3959 - acc: 0.8608
# Epoch 00015: saving model to weights.15-0.3894.hdf5
# 908/908 [==============================] - 50s 55ms/step - loss: 0.3957 - acc: 0.8609 - val_loss: 0.3894 - val_acc: 0.8637
# Epoch 16/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.3938 - acc: 0.8636
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 908/908 [==============================] - 51s 56ms/step - loss: 0.3936 - acc: 0.8636 - val_loss: 0.3874 - val_acc: 0.8661
# Epoch 17/50
# 908/908 [==============================] - 51s 56ms/step - loss: 0.3765 - acc: 0.8663 - val_loss: 0.3827 - val_acc: 0.8675
# Epoch 18/50
# 908/908 [==============================] - 50s 55ms/step - loss: 0.3870 - acc: 0.8620 - val_loss: 0.3840 - val_acc: 0.8693
# Epoch 19/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.3893 - acc: 0.8613
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 908/908 [==============================] - 53s 58ms/step - loss: 0.3896 - acc: 0.8611 - val_loss: 0.3828 - val_acc: 0.8664
# Epoch 20/50
#  61/908 [=>............................] - ETA: 36s - loss: 0.4084 - acc: 0.8623

# %%
model.layers[0].trainable = True
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Model)             (None, 2048)              20861480
# _________________________________________________________________
# dense (Dense)                (None, 6)                 12294
# =================================================================
# Total params: 20,873,774
# Trainable params: 20,819,246
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
FAST_RUN = False
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validate_generator,
    validation_steps=validate.shape[0]//batch_size,
    steps_per_epoch=train.shape[0]//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 908/908 [==============================] - 128s 141ms/step - loss: 0.5142 - acc: 0.8343 - val_loss: 0.4431 - val_acc: 0.8778
# Epoch 2/50
# 908/908 [==============================] - 117s 129ms/step - loss: 0.3176 - acc: 0.8943 - val_loss: 0.3823 - val_acc: 0.8878
# Epoch 3/50
# 908/908 [==============================] - 117s 129ms/step - loss: 0.2591 - acc: 0.9155 - val_loss: 0.6148 - val_acc: 0.7974
# Epoch 4/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.2311 - acc: 0.9218
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 908/908 [==============================] - 119s 131ms/step - loss: 0.2315 - acc: 0.9217 - val_loss: 0.3830 - val_acc: 0.8675
# Epoch 5/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.1169 - acc: 0.9612
# Epoch 00005: saving model to weights.05-0.2608.hdf5
# 908/908 [==============================] - 120s 132ms/step - loss: 0.1170 - acc: 0.9612 - val_loss: 0.2608 - val_acc: 0.9142
# Epoch 6/50
# 908/908 [==============================] - 118s 130ms/step - loss: 0.0870 - acc: 0.9703 - val_loss: 0.3037 - val_acc: 0.9116
# Epoch 7/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.0713 - acc: 0.9756
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 908/908 [==============================] - 117s 129ms/step - loss: 0.0715 - acc: 0.9756 - val_loss: 0.2872 - val_acc: 0.9116
# Epoch 8/50
# 908/908 [==============================] - 118s 130ms/step - loss: 0.0314 - acc: 0.9896 - val_loss: 0.2848 - val_acc: 0.9216
# Epoch 9/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.0175 - acc: 0.9943
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 908/908 [==============================] - 118s 130ms/step - loss: 0.0175 - acc: 0.9943 - val_loss: 0.3314 - val_acc: 0.9207
# Epoch 10/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.0091 - acc: 0.9972
# Epoch 00010: saving model to weights.10-0.3070.hdf5
# 908/908 [==============================] - 119s 131ms/step - loss: 0.0091 - acc: 0.9972 - val_loss: 0.3070 - val_acc: 0.9304
# Epoch 11/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9984
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 908/908 [==============================] - 118s 130ms/step - loss: 0.0052 - acc: 0.9984 - val_loss: 0.3209 - val_acc: 0.9304
# Epoch 12/50
# 908/908 [==============================] - 118s 129ms/step - loss: 0.0044 - acc: 0.9987 - val_loss: 0.3297 - val_acc: 0.9301
# Epoch 13/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9988
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 908/908 [==============================] - 118s 130ms/step - loss: 0.0043 - acc: 0.9988 - val_loss: 0.3228 - val_acc: 0.9301
# Epoch 14/50
# 908/908 [==============================] - 118s 130ms/step - loss: 0.0021 - acc: 0.9992 - val_loss: 0.3281 - val_acc: 0.9336
# Epoch 15/50
# 907/908 [============================>.] - ETA: 0s - loss: 0.0020 - acc: 0.9990
# Epoch 00015: saving model to weights.15-0.3350.hdf5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 908/908 [==============================] - 117s 129ms/step - loss: 0.0020 - acc: 0.9990 - val_loss: 0.3350 - val_acc: 0.9313
# Epoch 00015: early stopping

# %%
test_files = os.listdir(input0+"/test")
test = pd.DataFrame({
    'image_name': test_files
})

# %%
test_generator = datagen.flow_from_dataframe(
    test, 
    input0+"/test/", 
    x_col='image_name',
    y_col=None,
    class_mode=None,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 7301 images.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(test.shape[0]/batch_size))

# %%
y_pred = predict.argmax(axis=-1)

# %%
y_pred
# Out:
# array([1, 0, 2, ..., 1, 0, 3])

# %%
test['label'] = y_pred

# %%
test.head(10)
# Out:
#   image_name  label
# 0   8785.jpg      1
# 1  10679.jpg      0
# 2  20675.jpg      2
# 3  21831.jpg      4
# 4  14093.jpg      5
# 5   7723.jpg      5
# 6  19341.jpg      3
# 7  14587.jpg      1
# 8  11953.jpg      4
# 9   6162.jpg      5

# %%
from keras.preprocessing.image import load_img
sample_test = test.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['image_name']
    category = row['label']
    img = load_img(input0+"/test/"+filename, target_size=(image_size, image_size))
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')')
plt.tight_layout()
plt.show()
# Out:
# Using TensorFlow backend.

# %%
test.to_csv('submission.csv', index=False)
